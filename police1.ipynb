# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:/GUVI PRACTICE/traffic_stops - traffic_stops_with_vehicle_number.csv")
df
# Out:
# C:\Users\Sneha R\AppData\Local\Temp\ipykernel_5732\1483686486.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("D:/GUVI PRACTICE/traffic_stops - traffic_stops_with_vehicle_number.csv")
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# ...

# %%
df.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name              0
# driver_gender             0
# driver_age_raw            0
# driver_age                0
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           21720
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# vehicle_number            0
# dtype: int64

# %%
df['search_type'] = df['search_type'].replace(np.nan, 'None')

# %%
df.drop(columns=['driver_age_raw','violation_raw'],inplace=True)
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      2020-01-01   0:00:00       Canada             M          19
# 1      2020-01-01   0:01:00        India             M          58
# 2      2020-01-01   0:02:00          USA             M          76
# 3      2020-01-01   0:03:00       Canada             M          76
# 4      2020-01-01   0:04:00       Canada             M          75
# ...           ...       ...          ...           ...         ...
# 65533  2020-02-15  12:13:00        India             F          48
# 65534  2020-02-15  12:14:00       Canada             F          35
# 65535  2020-02-15  12:15:00          USA             M          41
# 65536  2020-02-15  12:16:00       Canada             F          63
# 65537  2020-02-15  12:17:00          USA             F          32
#
#       driver_race violation  search_conducted     search_type stop_outcome  \
# 0           Asian  Speeding              True  Vehicle Search       Ticket
# ...

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pymysql

# %%
myconnection = pymysql.connect(host = 'localhost',user='root',passwd='Sneharajendran@1672k')
cursor = myconnection.cursor()
cursor.execute("CREATE DATABASE IF NOT EXISTS police_log;")
print("Database created successfully")

myconnection = pymysql.connect(
    host = 'localhost',
    user='root',
    passwd='Sneharajendran@1672k',
    database = "police_log")

cursor = myconnection.cursor()

cursor.execute("use police_log;")
# Out:
# Database created successfully
# 0

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS police_log_stops(
    stop_id INT AUTO_INCREMENT PRIMARY KEY,                       
    stop_date DATE,
    stop_time TIME,
    country_name VARCHAR(100),
    driver_gender VARCHAR(10),
    driver_age INT,
    driver_race VARCHAR(50),
    violation VARCHAR(255),
    search_conducted BOOLEAN,
    search_type VARCHAR(255),
    stop_outcome VARCHAR(100),
    is_arrested BOOLEAN,
    stop_duration VARCHAR(50),
    drugs_related_stop BOOLEAN,
    vehicle_number VARCHAR(50) 
);
""")
# Out:
# 0

# %%
insert_query = """
INSERT INTO police_log_stops (
    stop_date, stop_time, country_name, driver_gender, driver_age,
    driver_race, violation, search_conducted, search_type, stop_outcome,
    is_arrested, stop_duration, drugs_related_stop, vehicle_number
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

data = [(
    row['stop_date'], row['stop_time'], row['country_name'], row['driver_gender'],
    row['driver_age'], row['driver_race'], row['violation'], row['search_conducted'],
    row['search_type'], row['stop_outcome'], row['is_arrested'], row['stop_duration'],
    row['drugs_related_stop'], row['vehicle_number']
) for _, row in df.iterrows()]

cursor.executemany(insert_query, data)
myconnection.commit()
cursor.close()
myconnection.close()
print("Data inserted successfully!")
# Out:
# Data inserted successfully!
